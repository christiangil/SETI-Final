# %%
#working directly from breakthrough/GBT/voyager/voyager.ipynb
#Using Python 2 and the Waterfall.py method of importing filterbank files
#https://github.com/UCBerkeleySETI/breakthrough/blob/master/GBT/voyager/voyager.ipynb

import pylab as plt
from blimpy2 import Waterfall
# %matplotlib inline

obs = Waterfall('voyager_f1032192_t300_v2.fil')
obs.info()
# Out:
# C:\Users\Christian\Anaconda2\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# blimpy2\filterbank.py:57: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\Christian\Anaconda2\lib\runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "C:\Users\Christian\Anaconda2\lib\runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a8a7fedfe47c>", line 4, in <module>
#     import pylab as plt
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\pylab.py", line 1, in <module>
#     from matplotlib.pylab import *
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\pylab.py", line 257, in <module>
#     from matplotlib import cbook, mlab, pyplot as plt
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\pyplot.py", line 72, in <module>
#     from matplotlib.backends import pylab_setup
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# blimpy2\guppi.py:30: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\Christian\Anaconda2\lib\runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "C:\Users\Christian\Anaconda2\lib\runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a8a7fedfe47c>", line 4, in <module>
#     import pylab as plt
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\pylab.py", line 1, in <module>
#     from matplotlib.pylab import *
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\pylab.py", line 257, in <module>
#     from matplotlib import cbook, mlab, pyplot as plt
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\pyplot.py", line 72, in <module>
#     from matplotlib.backends import pylab_setup
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# blimpy2\waterfall.py:52: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\Christian\Anaconda2\lib\runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "C:\Users\Christian\Anaconda2\lib\runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-a8a7fedfe47c>", line 4, in <module>
#     import pylab as plt
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\pylab.py", line 1, in <module>
#     from matplotlib.pylab import *
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\pylab.py", line 257, in <module>
#     from matplotlib import cbook, mlab, pyplot as plt
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\pyplot.py", line 72, in <module>
#     from matplotlib.backends import pylab_setup
#   File "C:\Users\Christian\Anaconda2\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# --- File Info ---
#     telescope_id :                                6
#      rawdatafile : ./blc3_2bit_guppi_57386_VOYAGER1_0004.0000.raw
#      source_name :                         VOYAGER1
#           tstart :                    57386.8649074
#        data_type :                                1
#           nchans :                         66060288
#            ibeam :                                1
#            tsamp :                      105.6964608
#             foff :               -2.83831641788e-06
#          src_raj :                     17:11:58.728
#          src_dej :                      11:56:57.48
#           nbeams :                                1
#         az_start :                              0.0
#             fch1 :                    8588.96484233
#         za_start :                              0.0
#       machine_id :                               20
#             nifs :                                1
#            nbits :                               32
#
# Num ints in file :                                2
#       File shape :                (2L, 1, 66060288)
# --- Selection Info ---
# Data selection shape :                 (2, 1, 66060288)
# Minimum freq (MHz) :                    8401.46484233
# Maximum freq (MHz) :                    8588.96484233

# %%
print obs.header
print obs.data.shape
# Out:
# {'telescope_id': 6, 'rawdatafile': './blc3_2bit_guppi_57386_VOYAGER1_0004.0000.raw', 'source_name': 'VOYAGER1', 'tstart': 57386.864907407406, 'data_type': 1, 'nchans': 66060288, 'ibeam': 1, 'tsamp': 105.6964608, 'foff': -2.838316417875744e-06, 'src_raj': <Angle 17.19964667 hourangle>, 'src_dej': <Angle 11.9493 deg>, 'nbeams': 1, 'az_start': 0.0, 'fch1': 8588.964842330843, 'za_start': 0.0, 'machine_id': 20, 'nifs': 1, 'nbits': 32}
# (2, 1, 66060288)

# %%
obs.plot_spectrum()
fig = plt.gcf()
fig.savefig("justwork5.png", bbox_inches="tight")
# Out:
# extracting integration 0...

# %%
obs.plot_spectrum(f_start=8420.18, f_stop=8420.25)
# Out:
# extracting integration 0...

# %%
plt.figure(figsize=(8, 6))
plt.subplot(3,1,1)
obs.plot_spectrum(f_start=8420.193, f_stop=8420.195) # left sideband
plt.subplot(3,1,2)
obs.plot_spectrum(f_start=8420.2163, f_stop=8420.2166) # carrier
plt.subplot(3,1,3)
obs.plot_spectrum(f_start=8420.238, f_stop=8420.24) # right sideband
plt.tight_layout()
# Out:
# extracting integration 0...
# extracting integration 0...
# extracting integration 0...

# %%
plt.figure(figsize=(10,6))
obs.plot_waterfall()

# %%
plt.figure(figsize=(10, 18))
plt.subplot(3,1,1)
obs.plot_waterfall(f_start=8420.193, f_stop=8420.195) # left sideband
plt.subplot(3,1,2)
obs.plot_waterfall(f_start=8420.2163, f_stop=8420.2166) # carrier
plt.subplot(3,1,3)
obs.plot_waterfall(f_start=8420.238, f_stop=8420.24) # right sideband
plt.tight_layout()
